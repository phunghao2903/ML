# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Định nghĩa mã cổ phiếu và khoảng thời gian lấy dữ liệu
ma_cophieu = "BSI.VN"
khoang_thoi_gian = "60d"  # Lấy dữ liệu trong 60 ngày gần nhất
buoc_thoi_gian = "2m"     # Khoảng thời gian 5 phút

# Tải dữ liệu từ Yahoo Finance
data = yf.download(ma_cophieu, period=khoang_thoi_gian, interval=buoc_thoi_gian)

# Kiểm tra dữ liệu
# print(data.head())
data
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price                        Close     High      Low     Open Volume
# Ticker                      BSI.VN   BSI.VN   BSI.VN   BSI.VN BSI.VN
# Datetime
# 2025-02-24 02:14:00+00:00  46450.0  46700.0  46450.0  46700.0      0
# 2025-02-24 02:18:00+00:00  46450.0  46450.0  46450.0  46450.0   1000
# 2025-02-24 02:20:00+00:00  46400.0  46400.0  46400.0  46400.0    400
# 2025-02-24 02:22:00+00:00  46550.0  46550.0  46400.0  46400.0  11600
# 2025-02-24 02:24:00+00:00  46950.0  46950.0  46550.0  46550.0  51000
# ...                            ...      ...      ...      ...    ...
# 2025-04-09 07:20:00+00:00  46250.0  46250.0  46250.0  46250.0  26400
# 2025-04-09 07:22:00+00:00  46250.0  46250.0  46250.0  46250.0  19200
# 2025-04-09 07:26:00+00:00  46250.0  46250.0  46250.0  46250.0    700
# 2025-04-09 07:28:00+00:00  46250.0  46250.0  46250.0  46250.0   1800
# 2025-04-09 07:44:00+00:00  46250.0  46250.0  46250.0  46250.0  12800
#
# [3489 rows x 5 columns]

# %%
# Lựa chọn cột giá đóng cửa và loại bỏ các giá trị NaN
data = data[['Close']].dropna()

# Chuẩn hóa dữ liệu về khoảng [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

# Chia dữ liệu thành tập huấn luyện và kiểm tra (80% huấn luyện, 20% kiểm tra)
train_size = int(len(data_scaled) * 0.8)
train_data = data_scaled[:train_size]
test_data = data_scaled[train_size:]

# Hàm tạo tập dữ liệu theo định dạng phù hợp cho LSTM
def create_dataset(dataset, time_step=50):
    X, Y = [], []
    for i in range(len(dataset) - time_step):
        X.append(dataset[i:(i + time_step), 0])
        Y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(Y)

# Tạo tập huấn luyện và kiểm tra
time_step = 50  # Sử dụng 30 khoảng thời gian trước đó để dự đoán
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# Reshape dữ liệu để phù hợp với đầu vào của LSTM (samples, time steps, features)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Khởi tạo mô hình LSTM
model = Sequential([
    LSTM(units=32, return_sequences=True, input_shape=(time_step, 1)),
    Dropout(0.2),
    LSTM(units=50, return_sequences=True),
    Dropout(0.2),
    LSTM(units=50),
    Dropout(0.2),
    Dense(units=1)
])

# Biên dịch mô hình
model.compile(optimizer='adam', loss='mean_squared_error')

# Thiết lập hàm dừng sớm để tránh overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Huấn luyện mô hình
history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=30,
    validation_split=0.2,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 7s 26ms/step - loss: 0.0983 - val_loss: 0.0061
# Epoch 2/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0066 - val_loss: 0.0011
# Epoch 3/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0054 - val_loss: 0.0051
# Epoch 4/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0052 - val_loss: 0.0047
# Epoch 5/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0049 - val_loss: 0.0013
# Epoch 6/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0043 - val_loss: 0.0010
# Epoch 7/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0049 - val_loss: 0.0032
# Epoch 8/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0038 - val_loss: 0.0025
# Epoch 9/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0038 - val_loss: 0.0014
# Epoch 10/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0043 - val_loss: 0.0023
# Epoch 11/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0041 - val_loss: 0.0029
# Epoch 12/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0038 - val_loss: 0.0011
# Epoch 13/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0036 - val_loss: 0.0011
# Epoch 14/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0029 - val_loss: 0.0028
# Epoch 15/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0040 - val_loss: 9.9664e-04
# Epoch 16/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0028 - val_loss: 0.0010
# Epoch 17/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0032 - val_loss: 0.0037
# Epoch 18/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0031 - val_loss: 0.0043
# Epoch 19/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0031 - val_loss: 9.9157e-04
# Epoch 20/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0028 - val_loss: 9.5070e-04
# Epoch 21/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0029 - val_loss: 9.0629e-04
# Epoch 22/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0026 - val_loss: 0.0012
# Epoch 23/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0027 - val_loss: 0.0012
# Epoch 24/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0025 - val_loss: 8.5845e-04
# Epoch 25/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0024 - val_loss: 9.9892e-04
# Epoch 26/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0023 - val_loss: 0.0015
# Epoch 27/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 28/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022 - val_loss: 9.0321e-04
# Epoch 29/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0022 - val_loss: 0.0012
# Epoch 30/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0025 - val_loss: 9.2510e-04
# Epoch 31/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0019 - val_loss: 0.0011
# Epoch 32/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0019 - val_loss: 7.6165e-04
# Epoch 33/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0019 - val_loss: 0.0019
# Epoch 34/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0018 - val_loss: 7.3991e-04
# Epoch 35/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0023 - val_loss: 0.0011
# Epoch 36/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 7.9839e-04
# Epoch 37/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 0.0018
# Epoch 38/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 0.0013
# Epoch 39/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0018 - val_loss: 7.0452e-04
# Epoch 40/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0017 - val_loss: 0.0014
# Epoch 41/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0016 - val_loss: 0.0010
# Epoch 42/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0016 - val_loss: 0.0027
# Epoch 43/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0016 - val_loss: 8.6641e-04
# Epoch 44/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0016 - val_loss: 7.6819e-04
# Epoch 45/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0014 - val_loss: 6.8137e-04
# Epoch 46/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0013 - val_loss: 0.0011
# Epoch 47/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0016 - val_loss: 6.2564e-04
# Epoch 48/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0015 - val_loss: 0.0012
# Epoch 49/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0014 - val_loss: 6.3745e-04
# Epoch 50/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 51/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 0.0012 - val_loss: 9.7431e-04
# Epoch 52/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 0.0011 - val_loss: 8.2153e-04
# Epoch 53/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 6.7789e-04
# Epoch 54/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0013 - val_loss: 0.0013
# Epoch 55/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0012 - val_loss: 7.4269e-04
# Epoch 56/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0010 - val_loss: 5.4695e-04
# Epoch 57/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 6.7523e-04
# Epoch 58/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0010 - val_loss: 8.9338e-04
# Epoch 59/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 9.4444e-04 - val_loss: 8.3261e-04
# Epoch 60/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0010 - val_loss: 7.6279e-04
# Epoch 61/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 8.5428e-04 - val_loss: 5.8248e-04
# Epoch 62/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 8.8647e-04 - val_loss: 0.0011
# Epoch 63/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.4009e-04 - val_loss: 9.9398e-04
# Epoch 64/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 9.0932e-04 - val_loss: 4.7219e-04
# Epoch 65/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.8620e-04 - val_loss: 4.8111e-04
# Epoch 66/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.0472e-04 - val_loss: 5.2448e-04
# Epoch 67/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.5355e-04 - val_loss: 4.6001e-04
# Epoch 68/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.2000e-04 - val_loss: 4.3498e-04
# Epoch 69/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.4499e-04 - val_loss: 4.6081e-04
# Epoch 70/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.5065e-04 - val_loss: 4.7328e-04
# Epoch 71/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.1867e-04 - val_loss: 4.7050e-04
# Epoch 72/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 7.2327e-04 - val_loss: 4.0072e-04
# Epoch 73/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 7.0025e-04 - val_loss: 6.5040e-04
# Epoch 74/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 6.5754e-04 - val_loss: 7.3021e-04
# Epoch 75/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.6470e-04 - val_loss: 4.6424e-04
# Epoch 76/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.6406e-04 - val_loss: 4.5279e-04
# Epoch 77/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.8272e-04 - val_loss: 4.1336e-04
# Epoch 78/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.7379e-04 - val_loss: 3.9773e-04
# Epoch 79/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.2050e-04 - val_loss: 4.6613e-04
# Epoch 80/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.5365e-04 - val_loss: 3.6844e-04
# Epoch 81/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 6.3000e-04 - val_loss: 4.5665e-04
# Epoch 82/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 5.9972e-04 - val_loss: 3.8764e-04
# Epoch 83/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.2489e-04 - val_loss: 5.7307e-04
# Epoch 84/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.7320e-04 - val_loss: 3.3891e-04
# Epoch 85/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.7710e-04 - val_loss: 5.0732e-04
# Epoch 86/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0870e-04 - val_loss: 3.2381e-04
# Epoch 87/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.6209e-04 - val_loss: 6.0335e-04
# Epoch 88/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.1978e-04 - val_loss: 2.8999e-04
# Epoch 89/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.0843e-04 - val_loss: 8.6300e-04
# Epoch 90/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.5603e-04 - val_loss: 8.5690e-04
# Epoch 91/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.5942e-04 - val_loss: 3.1676e-04
# Epoch 92/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.8662e-04 - val_loss: 2.7519e-04
# Epoch 93/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.3021e-04 - val_loss: 2.6126e-04
# Epoch 94/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.3368e-04 - val_loss: 3.1285e-04
# Epoch 95/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.6617e-04 - val_loss: 2.6004e-04
# Epoch 96/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.0406e-04 - val_loss: 2.9434e-04
# Epoch 97/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.7100e-04 - val_loss: 3.1280e-04
# Epoch 98/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.0039e-04 - val_loss: 3.5316e-04
# Epoch 99/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4994e-04 - val_loss: 2.5492e-04
# Epoch 100/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3136e-04 - val_loss: 6.6600e-04
# Epoch 101/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.6157e-04 - val_loss: 5.6421e-04
# Epoch 102/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 4.9174e-04 - val_loss: 2.7491e-04
# Epoch 103/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 5.9918e-04 - val_loss: 2.3545e-04
# Epoch 104/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2778e-04 - val_loss: 2.3007e-04
# Epoch 105/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0015 - val_loss: 3.4639e-04
# Epoch 106/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.2461e-04 - val_loss: 3.2480e-04
# Epoch 107/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.7979e-04 - val_loss: 2.1051e-04
# Epoch 108/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.8831e-04 - val_loss: 3.3884e-04
# Epoch 109/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.9212e-04 - val_loss: 2.3134e-04
# Epoch 110/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.5842e-04 - val_loss: 2.8075e-04
# Epoch 111/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2502e-04 - val_loss: 2.0962e-04
# Epoch 112/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2685e-04 - val_loss: 2.0641e-04
# Epoch 113/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 4.2869e-04 - val_loss: 3.3057e-04
# Epoch 114/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.7988e-04 - val_loss: 3.7597e-04
# Epoch 115/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3006e-04 - val_loss: 2.5671e-04
# Epoch 116/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4305e-04 - val_loss: 1.9696e-04
# Epoch 117/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.5478e-04 - val_loss: 3.9044e-04
# Epoch 118/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5305e-04 - val_loss: 3.0015e-04
# Epoch 119/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4646e-04 - val_loss: 1.9405e-04
# Epoch 120/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8020e-04 - val_loss: 2.2015e-04
# Epoch 121/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.8584e-04 - val_loss: 1.8404e-04
# Epoch 122/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0327e-04 - val_loss: 2.6494e-04
# Epoch 123/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 3.7894e-04 - val_loss: 2.1935e-04
# Epoch 124/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - loss: 4.5878e-04 - val_loss: 1.8345e-04
# Epoch 125/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 4.5389e-04 - val_loss: 1.8461e-04
# Epoch 126/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4454e-04 - val_loss: 2.5913e-04
# Epoch 127/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.6634e-04 - val_loss: 7.5609e-04
# Epoch 128/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.6909e-04 - val_loss: 2.1739e-04
# Epoch 129/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.7179e-04 - val_loss: 2.0969e-04
# Epoch 130/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8343e-04 - val_loss: 1.9251e-04
# Epoch 131/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0912e-04 - val_loss: 1.8094e-04
# Epoch 132/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.5093e-04 - val_loss: 1.9139e-04
# Epoch 133/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.7462e-04 - val_loss: 1.7706e-04
# Epoch 134/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 5.2472e-04 - val_loss: 2.4688e-04
# Epoch 135/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 4.9761e-04 - val_loss: 4.2861e-04
# Epoch 136/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.5389e-04 - val_loss: 1.7546e-04
# Epoch 137/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.3746e-04 - val_loss: 2.5846e-04
# Epoch 138/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.7665e-04 - val_loss: 1.6899e-04
# Epoch 139/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4601e-04 - val_loss: 2.9237e-04
# Epoch 140/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.0253e-04 - val_loss: 5.0120e-04
# Epoch 141/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.4010e-04 - val_loss: 2.2471e-04
# Epoch 142/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2025e-04 - val_loss: 1.9691e-04
# Epoch 143/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 3.9109e-04 - val_loss: 2.7950e-04
# Epoch 144/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.6771e-04 - val_loss: 1.6740e-04
# Epoch 145/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.7225e-04 - val_loss: 3.1523e-04
# Epoch 146/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2428e-04 - val_loss: 2.9255e-04
# Epoch 147/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3688e-04 - val_loss: 1.9406e-04
# Epoch 148/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.5458e-04 - val_loss: 1.8249e-04
# Epoch 149/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8956e-04 - val_loss: 2.5519e-04
# Epoch 150/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.7581e-04 - val_loss: 1.6111e-04
# Epoch 151/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.2743e-04 - val_loss: 4.4597e-04
# Epoch 152/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.6548e-04 - val_loss: 1.7033e-04
# Epoch 153/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0837e-04 - val_loss: 1.6595e-04
# Epoch 154/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 4.0831e-04 - val_loss: 2.1480e-04
# Epoch 155/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 3.9682e-04 - val_loss: 2.2882e-04
# Epoch 156/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 5.0809e-04 - val_loss: 1.6473e-04
# Epoch 157/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8062e-04 - val_loss: 3.9108e-04
# Epoch 158/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3479e-04 - val_loss: 1.7775e-04
# Epoch 159/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4661e-04 - val_loss: 1.6087e-04
# Epoch 160/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3771e-04 - val_loss: 1.6579e-04
# Epoch 161/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 3.7925e-04 - val_loss: 2.5561e-04
# Epoch 162/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 3.9529e-04 - val_loss: 1.7844e-04
# Epoch 163/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 22ms/step - loss: 3.5341e-04 - val_loss: 1.6219e-04
# Epoch 164/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 25ms/step - loss: 3.8759e-04 - val_loss: 1.5832e-04
# Epoch 165/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 3.9675e-04 - val_loss: 2.3877e-04
# Epoch 166/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.3208e-04 - val_loss: 1.5873e-04
# Epoch 167/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.4800e-04 - val_loss: 2.0412e-04
# Epoch 168/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 4.1342e-04 - val_loss: 7.0685e-04
# Epoch 169/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 4.4580e-04 - val_loss: 1.6115e-04
# Epoch 170/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.8509e-04 - val_loss: 3.9028e-04
# Epoch 171/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.4572e-04 - val_loss: 3.1085e-04
# Epoch 172/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8028e-04 - val_loss: 1.8909e-04
# Epoch 173/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 3.8189e-04 - val_loss: 1.6047e-04
# Epoch 174/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 3.6836e-04 - val_loss: 3.1907e-04

# %%
# Dự đoán trên tập kiểm tra
y_pred = model.predict(X_test)

# Đưa dữ liệu dự đoán và thực tế về giá trị gốc
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Vẽ biểu đồ so sánh giá thực tế và giá dự đoán
plt.figure(figsize=(14, 5))
plt.plot(data.index[train_size + time_step:], y_test_inv, color='blue', label='Giá thực tế')
plt.plot(data.index[train_size + time_step:], y_pred_inv, color='red', label='Giá dự đoán')
plt.title('Dự đoán giá cổ phiếu với LSTM')
plt.xlabel('Thời gian')
plt.ylabel('Giá cổ phiếu')
plt.legend()
plt.show()



# y_pred = model.predict(X_test)
# y_pred = scaler.inverse_transform(y_pred)
# y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Tính các metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100

print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"MAPE: {mape}%")
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step
# RMSE: 405.3912297717491
# MAE: 212.48838372878083
# MAPE: 0.42322502436627707%

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import matplotlib.pyplot as plt

# --- HỒI QUY ---
# Tính các metrics hồi quy
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100

print("----- HỒI QUY -----")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.2f}%")

# --- PHÂN LOẠI (TĂNG / GIẢM) ---
# Chuyển y_test và y_pred về nhãn nhị phân: 1 nếu tăng, 0 nếu giảm
y_test_label = (y_test_inv[1:] > y_test_inv[:-1]).astype(int).flatten()
y_pred_label = (y_pred_inv[1:] > y_pred_inv[:-1]).astype(int).flatten()

# Cắt cho khớp độ dài
min_len = min(len(y_test_label), len(y_pred_label))
y_test_label = y_test_label[:min_len]
y_pred_label = y_pred_label[:min_len]

# Tính các chỉ số phân loại
acc = accuracy_score(y_test_label, y_pred_label)
prec = precision_score(y_test_label, y_pred_label, zero_division=0)
rec = recall_score(y_test_label, y_pred_label, zero_division=0)
f1 = f1_score(y_test_label, y_pred_label, zero_division=0)

print("\n----- PHÂN LOẠI (TĂNG/GIẢM) -----")
print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"F1-score:  {f1:.4f}")
# Out:
# ----- HỒI QUY -----
# RMSE: 405.3912
# MAE:  212.4884
# MAPE: 0.42%
#
# ----- PHÂN LOẠI (TĂNG/GIẢM) -----
# Accuracy:  0.6414
# Precision: 0.3482
# Recall:    0.4756
# F1-score:  0.4021

# %%
model.save('/content/train_BSI_1d_adam.keras')
