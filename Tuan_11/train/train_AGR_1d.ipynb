# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2025-03-30 13:40:51.568557: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-03-30 13:40:51.573397: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-30 13:40:51.626668: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-03-30 13:40:51.683594: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1743316851.728945    7992 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1743316851.753659    7992 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-03-30 13:40:51.893192: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Định nghĩa mã cổ phiếu và khoảng thời gian lấy dữ liệu
ma_cophieu = "AGR.VN"
khoang_thoi_gian = "60d"  # Lấy dữ liệu trong 60 ngày gần nhất
buoc_thoi_gian = "5m"     # Khoảng thời gian 5 phút

# Tải dữ liệu từ Yahoo Finance
data = yf.download(ma_cophieu, period=khoang_thoi_gian, interval=buoc_thoi_gian)

# Kiểm tra dữ liệu
print(data.head())
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price                        Close     High      Low     Open Volume
# Ticker                      AGR.VN   AGR.VN   AGR.VN   AGR.VN AGR.VN
# Datetime
# 2025-01-06 02:15:00+00:00  16850.0  16850.0  16850.0  16850.0   1100
# 2025-01-06 02:25:00+00:00  16850.0  16850.0  16850.0  16850.0    100
# 2025-01-06 02:30:00+00:00  16850.0  16850.0  16850.0  16850.0   5300
# 2025-01-06 02:40:00+00:00  16850.0  16850.0  16850.0  16850.0   2500
# 2025-01-06 02:45:00+00:00  16850.0  16850.0  16850.0  16850.0    500

# %%
# Lựa chọn cột giá đóng cửa và loại bỏ các giá trị NaN
data = data[['Close']].dropna()

# Chuẩn hóa dữ liệu về khoảng [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

# Chia dữ liệu thành tập huấn luyện và kiểm tra (80% huấn luyện, 20% kiểm tra)
train_size = int(len(data_scaled) * 0.8)
train_data = data_scaled[:train_size]
test_data = data_scaled[train_size:]

# Hàm tạo tập dữ liệu theo định dạng phù hợp cho LSTM
def create_dataset(dataset, time_step=30):
    X, Y = [], []
    for i in range(len(dataset) - time_step):
        X.append(dataset[i:(i + time_step), 0])
        Y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(Y)

# Tạo tập huấn luyện và kiểm tra
time_step = 30  # Sử dụng 30 khoảng thời gian trước đó để dự đoán
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# Reshape dữ liệu để phù hợp với đầu vào của LSTM (samples, time steps, features)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Khởi tạo mô hình LSTM
model = Sequential([
    LSTM(units=50, return_sequences=True, input_shape=(time_step, 1)),
    Dropout(0.3),
    LSTM(units=50, return_sequences=True),
    Dropout(0.3),
    LSTM(units=50),
    Dropout(0.3),
    Dense(units=1)
])

# Biên dịch mô hình
model.compile(optimizer='adam', loss='mean_squared_error')

# Thiết lập hàm dừng sớm để tránh overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Huấn luyện mô hình
history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=30,
    validation_split=0.2,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/200
# 2025-03-30 13:41:06.539170: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/levanhuy/development/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 3s 31ms/step - loss: 0.0290 - val_loss: 0.0017
# Epoch 2/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0034 - val_loss: 0.0016
# Epoch 3/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 0.0030 - val_loss: 0.0067
# Epoch 4/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0029 - val_loss: 0.0035
# Epoch 5/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 0.0026 - val_loss: 0.0026
# Epoch 6/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 7/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0022 - val_loss: 0.0043
# Epoch 8/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0023 - val_loss: 0.0013
# Epoch 9/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0020 - val_loss: 0.0022
# Epoch 10/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 11/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0020 - val_loss: 0.0027
# Epoch 12/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0021 - val_loss: 0.0012
# Epoch 13/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 14/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0016 - val_loss: 0.0014
# Epoch 15/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0017 - val_loss: 0.0024
# Epoch 16/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 17/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 18/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - val_loss: 0.0019
# Epoch 19/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0017 - val_loss: 0.0021
# Epoch 20/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 21/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0017 - val_loss: 0.0032
# Epoch 22/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0015 - val_loss: 0.0021
# Epoch 23/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0015 - val_loss: 0.0010
# Epoch 24/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0015 - val_loss: 0.0025
# Epoch 25/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0014 - val_loss: 0.0019
# Epoch 26/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0015 - val_loss: 9.8321e-04
# Epoch 27/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0014 - val_loss: 9.8736e-04
# Epoch 28/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0014 - val_loss: 0.0011
# Epoch 29/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - loss: 0.0012 - val_loss: 0.0013
# Epoch 30/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0016 - val_loss: 0.0038
# Epoch 31/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0016 - val_loss: 0.0013
# Epoch 32/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0015 - val_loss: 0.0013
# Epoch 33/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0013 - val_loss: 0.0021
# Epoch 34/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0012 - val_loss: 8.8824e-04
# Epoch 35/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0010 - val_loss: 0.0014
# Epoch 36/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0013 - val_loss: 0.0010
# Epoch 37/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 0.0011 - val_loss: 8.2970e-04
# Epoch 38/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0013 - val_loss: 8.6375e-04
# Epoch 39/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0011 - val_loss: 0.0047
# Epoch 40/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0012 - val_loss: 0.0034
# Epoch 41/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0012 - val_loss: 8.0987e-04
# Epoch 42/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 43/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - loss: 0.0011 - val_loss: 0.0011
# Epoch 44/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0011 - val_loss: 7.9186e-04
# Epoch 45/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.7930e-04 - val_loss: 9.3317e-04
# Epoch 46/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0012 - val_loss: 0.0017
# Epoch 47/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0010 - val_loss: 8.0951e-04
# Epoch 48/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0011 - val_loss: 8.2230e-04
# Epoch 49/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0011 - val_loss: 7.8120e-04
# Epoch 50/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 2s 30ms/step - loss: 0.0012 - val_loss: 8.5305e-04
# Epoch 51/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0010 - val_loss: 8.4227e-04
# Epoch 52/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0011 - val_loss: 7.4655e-04
# Epoch 53/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 8.5558e-04 - val_loss: 0.0018
# Epoch 54/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 0.0010 - val_loss: 9.8979e-04
# Epoch 55/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 0.0010 - val_loss: 8.2443e-04
# Epoch 56/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 0.0010 - val_loss: 0.0010
# Epoch 57/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.4486e-04 - val_loss: 7.1059e-04
# Epoch 58/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 59/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 0.0010 - val_loss: 8.5745e-04
# Epoch 60/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.3175e-04 - val_loss: 7.1003e-04
# Epoch 61/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 0.0011 - val_loss: 6.9032e-04
# Epoch 62/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0010 - val_loss: 0.0012
# Epoch 63/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.3776e-04 - val_loss: 0.0016
# Epoch 64/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.7366e-04 - val_loss: 0.0011
# Epoch 65/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.6970e-04 - val_loss: 7.4942e-04
# Epoch 66/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 9.1699e-04 - val_loss: 7.2243e-04
# Epoch 67/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 9.4701e-04 - val_loss: 0.0022
# Epoch 68/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 9.8845e-04 - val_loss: 6.7966e-04
# Epoch 69/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.4206e-04 - val_loss: 0.0013
# Epoch 70/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 7.9103e-04 - val_loss: 9.1099e-04
# Epoch 71/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 8.2856e-04 - val_loss: 0.0011
# Epoch 72/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.2401e-04 - val_loss: 0.0022
# Epoch 73/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - loss: 9.0305e-04 - val_loss: 7.5175e-04
# Epoch 74/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - loss: 9.3750e-04 - val_loss: 7.1957e-04
# Epoch 75/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 7.8812e-04 - val_loss: 0.0018
# Epoch 76/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 8.9976e-04 - val_loss: 8.5129e-04
# Epoch 77/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 9.9766e-04 - val_loss: 0.0030
# Epoch 78/200
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 1s 23ms/step - loss: 0.0013 - val_loss: 0.0013

# %%
# Dự đoán trên tập kiểm tra
y_pred = model.predict(X_test)

# Đưa dữ liệu dự đoán và thực tế về giá trị gốc
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Vẽ biểu đồ so sánh giá thực tế và giá dự đoán
plt.figure(figsize=(14, 5))
plt.plot(data.index[train_size + time_step:], y_test_inv, color='blue', label='Giá thực tế')
plt.plot(data.index[train_size + time_step:], y_pred_inv, color='red', label='Giá dự đoán')
plt.title('Dự đoán giá cổ phiếu với LSTM')
plt.xlabel('Thời gian')
plt.ylabel('Giá cổ phiếu')
plt.legend()
plt.show()
# Out:
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step

# %%
model.save('predict_AGR_1d.keras')
