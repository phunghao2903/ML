# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
# Định nghĩa mã cổ phiếu và khoảng thời gian lấy dữ liệu
ma_cophieu = "BSI.VN"
khoang_thoi_gian = "60d"  # Lấy dữ liệu trong 60 ngày gần nhất
buoc_thoi_gian = "2m"     # Khoảng thời gian 5 phút

# Tải dữ liệu từ Yahoo Finance
data = yf.download(ma_cophieu, period=khoang_thoi_gian, interval=buoc_thoi_gian)

# Kiểm tra dữ liệu
# print(data.head())
data
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price                        Close     High      Low     Open Volume
# Ticker                      BSI.VN   BSI.VN   BSI.VN   BSI.VN BSI.VN
# Datetime
# 2025-02-24 02:14:00+00:00  46450.0  46700.0  46450.0  46700.0      0
# 2025-02-24 02:18:00+00:00  46450.0  46450.0  46450.0  46450.0   1000
# 2025-02-24 02:20:00+00:00  46400.0  46400.0  46400.0  46400.0    400
# 2025-02-24 02:22:00+00:00  46550.0  46550.0  46400.0  46400.0  11600
# 2025-02-24 02:24:00+00:00  46950.0  46950.0  46550.0  46550.0  51000
# ...                            ...      ...      ...      ...    ...
# 2025-04-09 07:20:00+00:00  46250.0  46250.0  46250.0  46250.0  26400
# 2025-04-09 07:22:00+00:00  46250.0  46250.0  46250.0  46250.0  19200
# 2025-04-09 07:26:00+00:00  46250.0  46250.0  46250.0  46250.0    700
# 2025-04-09 07:28:00+00:00  46250.0  46250.0  46250.0  46250.0   1800
# 2025-04-09 07:44:00+00:00  46250.0  46250.0  46250.0  46250.0  12800
#
# [3500 rows x 5 columns]

# %%
# Lựa chọn cột giá đóng cửa và loại bỏ các giá trị NaN
data = data[['Close']].dropna()

# Chuẩn hóa dữ liệu về khoảng [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

# Chia dữ liệu thành tập huấn luyện và kiểm tra (80% huấn luyện, 20% kiểm tra)
train_size = int(len(data_scaled) * 0.8)
train_data = data_scaled[:train_size]
test_data = data_scaled[train_size:]

# Hàm tạo tập dữ liệu theo định dạng phù hợp cho LSTM
def create_dataset(dataset, time_step=50):
    X, Y = [], []
    for i in range(len(dataset) - time_step):
        X.append(dataset[i:(i + time_step), 0])
        Y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(Y)

# Tạo tập huấn luyện và kiểm tra
time_step = 50  # Sử dụng 30 khoảng thời gian trước đó để dự đoán
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# Reshape dữ liệu để phù hợp với đầu vào của LSTM (samples, time steps, features)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Khởi tạo mô hình LSTM
model = Sequential([
    LSTM(units=32, return_sequences=True, input_shape=(time_step, 1)),
    Dropout(0.2),
    LSTM(units=50, return_sequences=True),
    Dropout(0.2),
    LSTM(units=50),
    Dropout(0.2),
    Dense(units=1)
])

# Biên dịch mô hình
model.compile(optimizer='adam', loss='mean_squared_error')

# Thiết lập hàm dừng sớm để tránh overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Huấn luyện mô hình
history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=30,
    validation_split=0.2,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - loss: 0.0781 - val_loss: 0.0056
# Epoch 2/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - loss: 0.0063 - val_loss: 0.0012
# Epoch 3/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 0.0050 - val_loss: 0.0015
# Epoch 4/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0048 - val_loss: 0.0013
# Epoch 5/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0046 - val_loss: 0.0030
# Epoch 6/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0042 - val_loss: 0.0019
# Epoch 7/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0042 - val_loss: 0.0012
# Epoch 8/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0037 - val_loss: 0.0013
# Epoch 9/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0036 - val_loss: 0.0012
# Epoch 10/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0036 - val_loss: 0.0022
# Epoch 11/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0034 - val_loss: 0.0024
# Epoch 12/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0033 - val_loss: 0.0015
# Epoch 13/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - loss: 0.0036 - val_loss: 0.0018
# Epoch 14/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0034 - val_loss: 0.0022
# Epoch 15/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0031 - val_loss: 0.0015
# Epoch 16/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0032 - val_loss: 0.0014
# Epoch 17/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0028 - val_loss: 0.0011
# Epoch 18/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0032 - val_loss: 0.0030
# Epoch 19/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0028 - val_loss: 0.0042
# Epoch 20/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 21/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0030 - val_loss: 0.0027
# Epoch 22/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0025 - val_loss: 0.0012
# Epoch 23/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0024 - val_loss: 0.0023
# Epoch 24/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0023 - val_loss: 0.0019
# Epoch 25/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0024 - val_loss: 0.0011
# Epoch 26/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0023 - val_loss: 0.0014
# Epoch 27/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0021 - val_loss: 0.0017
# Epoch 28/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 29/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022 - val_loss: 8.0697e-04
# Epoch 30/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022 - val_loss: 8.7028e-04
# Epoch 31/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0022 - val_loss: 0.0017
# Epoch 32/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0019 - val_loss: 8.3259e-04
# Epoch 33/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 34/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0019 - val_loss: 0.0012
# Epoch 35/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0017 - val_loss: 9.4599e-04
# Epoch 36/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0017 - val_loss: 8.1711e-04
# Epoch 37/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0017 - val_loss: 0.0012
# Epoch 38/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0017 - val_loss: 7.5989e-04
# Epoch 39/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 40/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0018 - val_loss: 9.2397e-04
# Epoch 41/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0015 - val_loss: 8.3171e-04
# Epoch 42/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0014 - val_loss: 0.0010
# Epoch 43/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0015 - val_loss: 9.9408e-04
# Epoch 44/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0014 - val_loss: 7.4063e-04
# Epoch 45/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0014 - val_loss: 6.8118e-04
# Epoch 46/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0013 - val_loss: 7.3914e-04
# Epoch 47/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0012 - val_loss: 7.0583e-04
# Epoch 48/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 0.0012 - val_loss: 6.6796e-04
# Epoch 49/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0013 - val_loss: 8.4364e-04
# Epoch 50/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 8.5543e-04
# Epoch 51/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0012 - val_loss: 7.5901e-04
# Epoch 52/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 0.0011 - val_loss: 0.0012
# Epoch 53/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0011 - val_loss: 9.2467e-04
# Epoch 54/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 0.0011 - val_loss: 0.0016
# Epoch 55/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0011 - val_loss: 5.7055e-04
# Epoch 56/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 0.0010 - val_loss: 7.0154e-04
# Epoch 57/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 3s 34ms/step - loss: 0.0010 - val_loss: 5.3586e-04
# Epoch 58/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 9.6475e-04 - val_loss: 5.4927e-04
# Epoch 59/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 24ms/step - loss: 9.5691e-04 - val_loss: 8.9418e-04
# Epoch 60/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 23ms/step - loss: 8.3040e-04 - val_loss: 5.4575e-04
# Epoch 61/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.6067e-04 - val_loss: 8.4924e-04
# Epoch 62/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.1344e-04 - val_loss: 8.9494e-04
# Epoch 63/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 8.4875e-04 - val_loss: 0.0011
# Epoch 64/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 8.7833e-04 - val_loss: 5.2089e-04
# Epoch 65/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - loss: 8.1868e-04 - val_loss: 5.1054e-04
# Epoch 66/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.4121e-04 - val_loss: 4.6546e-04
# Epoch 67/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 8.5431e-04 - val_loss: 5.3267e-04
# Epoch 68/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0928e-04 - val_loss: 4.6731e-04
# Epoch 69/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0150e-04 - val_loss: 4.3121e-04
# Epoch 70/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.6944e-04 - val_loss: 5.1922e-04
# Epoch 71/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 7.1808e-04 - val_loss: 4.4659e-04
# Epoch 72/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.9268e-04 - val_loss: 4.4882e-04
# Epoch 73/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.4904e-04 - val_loss: 4.1014e-04
# Epoch 74/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.1119e-04 - val_loss: 7.0218e-04
# Epoch 75/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - loss: 6.8349e-04 - val_loss: 3.8737e-04
# Epoch 76/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.7798e-04 - val_loss: 6.0839e-04
# Epoch 77/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.1085e-04 - val_loss: 4.2910e-04
# Epoch 78/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.7510e-04 - val_loss: 3.9285e-04
# Epoch 79/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 5.4003e-04 - val_loss: 5.2831e-04
# Epoch 80/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 6.7079e-04 - val_loss: 6.9994e-04
# Epoch 81/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 6.4186e-04 - val_loss: 6.3021e-04
# Epoch 82/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 7.0654e-04 - val_loss: 5.5053e-04
# Epoch 83/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - loss: 5.7681e-04 - val_loss: 4.4665e-04
# Epoch 84/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - loss: 5.5969e-04 - val_loss: 5.4699e-04
# Epoch 85/200
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - loss: 6.1153e-04 - val_loss: 7.8427e-04

# %%
# Dự đoán trên tập kiểm tra
y_pred = model.predict(X_test)

# Đưa dữ liệu dự đoán và thực tế về giá trị gốc
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Vẽ biểu đồ so sánh giá thực tế và giá dự đoán
plt.figure(figsize=(14, 5))
plt.plot(data.index[train_size + time_step:], y_test_inv, color='blue', label='Giá thực tế')
plt.plot(data.index[train_size + time_step:], y_pred_inv, color='red', label='Giá dự đoán')
plt.title('Dự đoán giá cổ phiếu với LSTM')
plt.xlabel('Thời gian')
plt.ylabel('Giá cổ phiếu')
plt.legend()
plt.show()



# y_pred = model.predict(X_test)
# y_pred = scaler.inverse_transform(y_pred)
# y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Tính các metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100

print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"MAPE: {mape}%")
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# RMSE: 546.1955839421641
# MAE: 299.5963461538461
# MAPE: 0.5843498112187027%

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, accuracy_score, precision_score, recall_score, f1_score
import numpy as np
import matplotlib.pyplot as plt

# --- HỒI QUY ---
# Tính các metrics hồi quy
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100

print("----- HỒI QUY -----")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.2f}%")

# --- PHÂN LOẠI (TĂNG / GIẢM) ---
# Chuyển y_test và y_pred về nhãn nhị phân: 1 nếu tăng, 0 nếu giảm
y_test_label = (y_test_inv[1:] > y_test_inv[:-1]).astype(int).flatten()
y_pred_label = (y_pred_inv[1:] > y_pred_inv[:-1]).astype(int).flatten()

# Cắt cho khớp độ dài
min_len = min(len(y_test_label), len(y_pred_label))
y_test_label = y_test_label[:min_len]
y_pred_label = y_pred_label[:min_len]

# Tính các chỉ số phân loại
acc = accuracy_score(y_test_label, y_pred_label)
prec = precision_score(y_test_label, y_pred_label, zero_division=0)
rec = recall_score(y_test_label, y_pred_label, zero_division=0)
f1 = f1_score(y_test_label, y_pred_label, zero_division=0)

print("\n----- PHÂN LOẠI (TĂNG/GIẢM) -----")
print(f"Accuracy:  {acc:.4f}")
print(f"Precision: {prec:.4f}")
print(f"Recall:    {rec:.4f}")
print(f"F1-score:  {f1:.4f}")
# Out:
# ----- HỒI QUY -----
# RMSE: 546.1956
# MAE:  299.5963
# MAPE: 0.58%
#
# ----- PHÂN LOẠI (TĂNG/GIẢM) -----
# Accuracy:  0.5871
# Precision: 0.2899
# Recall:    0.4107
# F1-score:  0.3399
