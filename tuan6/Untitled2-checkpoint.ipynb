# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import os.path
import datetime as dt
import yfinance as yf
from os import path
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
stock = "HPG.VN"
start = dt.datetime(2010, 1, 1)
end = dt.datetime(2024, 1, 1)
df = yf.download(stock, start, end)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
df = df.reset_index()
df.head()
# Out:
# Price        Date        Close         High          Low         Open  \
# Ticker                  HPG.VN       HPG.VN       HPG.VN       HPG.VN
# 0      2010-01-04  2455.635986  2455.635986  2415.379639  2415.379639
# 1      2010-01-05  2576.405029  2576.405029  2455.635986  2576.405029
# 2      2010-01-06  2656.917725  2656.917725  2536.148682  2556.276855
# 3      2010-01-07  2737.430420  2777.686768  2656.917725  2697.174072
# 4      2010-01-08  2616.661377  2797.814941  2616.661377  2797.814941
#
# Price     Volume
# Ticker    HPG.VN
# 0       14981968
# 1       29885458
# 2       44009443
# 3       38150498
# 4       22580516

# %%
data_train = df[['Close']].values

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler(feature_range = (0, 1))

data_training = scaler.fit_transform(data_train)

x_train, y_train = [], []
no_of_sample = len(data_train)

# %%
for i in range(60, no_of_sample):
    x_train.append(data_training[i-60:i, 0])
    y_train.append(data_training[i, 0])

x_train, y_train = np.array(x_train), np.array(y_train)

x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
model = Sequential()
model.add(LSTM(units = 50, return_sequences = True, input_shape = (x_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.3))
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.4))
model.add(LSTM(units = 50))
model.add(Dropout(0.5))
model.add(Dense(units = 1))
model.compile(optimizer = 'adam', loss = 'mean_squared_error')
# Out:
# C:\Users\TANKUTO\AppData\Local\Programs\Python\Python39\lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
if path.exists("stock_future.keras"):
    model.load_weights("stock_future.keras")
else:
    model.fit(x_train, y_train, epochs = 100, batch_size = 32)
    model.save("stock_future.keras")
# Out:
# Epoch 1/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 18s 115ms/step - loss: 0.0187
# Epoch 2/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 12s 114ms/step - loss: 0.0049
# Epoch 3/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 13s 116ms/step - loss: 0.0046
# Epoch 4/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 13s 118ms/step - loss: 0.0040
# Epoch 5/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 11s 104ms/step - loss: 0.0028
# Epoch 6/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 0.0030
# Epoch 7/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 13s 123ms/step - loss: 0.0030
# Epoch 8/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 12s 110ms/step - loss: 0.0024
# Epoch 9/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 11s 106ms/step - loss: 0.0025
# Epoch 10/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 12s 107ms/step - loss: 0.0023
# Epoch 11/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 9s 86ms/step - loss: 0.0022
# Epoch 12/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 11s 104ms/step - loss: 0.0025
# Epoch 13/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 12s 109ms/step - loss: 0.0021
# Epoch 14/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 21s 109ms/step - loss: 0.0025
# Epoch 15/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 10s 89ms/step - loss: 0.0022
# Epoch 16/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 8s 71ms/step - loss: 0.0022
# Epoch 17/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 9s 84ms/step - loss: 0.0024
# Epoch 18/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 11s 98ms/step - loss: 0.0023
# Epoch 19/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 10s 92ms/step - loss: 0.0021
# Epoch 20/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - loss: 0.0021
# Epoch 21/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 19s 89ms/step - loss: 0.0018
# Epoch 22/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 12s 113ms/step - loss: 0.0023
# Epoch 23/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 11s 102ms/step - loss: 0.0020
# Epoch 24/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 13s 120ms/step - loss: 0.0017
# Epoch 25/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 10s 90ms/step - loss: 0.0021
# Epoch 26/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 11s 104ms/step - loss: 0.0018
# Epoch 27/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 12s 108ms/step - loss: 0.0018
# Epoch 28/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 9s 81ms/step - loss: 0.0020
# Epoch 29/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0024
# Epoch 30/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 5s 45ms/step - loss: 0.0018
# Epoch 31/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - loss: 0.0020
# Epoch 32/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - loss: 0.0019
# Epoch 33/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0018
# Epoch 34/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0016
# Epoch 35/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0017
# Epoch 36/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0021
# Epoch 37/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step - loss: 0.0017
# Epoch 38/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - loss: 0.0018
# Epoch 39/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0019
# Epoch 40/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0020
# Epoch 41/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0020
# Epoch 42/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0016
# Epoch 43/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0020
# Epoch 44/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0017
# Epoch 45/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.0018
# Epoch 46/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0019
# Epoch 47/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 59ms/step - loss: 0.0018
# Epoch 48/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 53ms/step - loss: 0.0020
# Epoch 49/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0021
# Epoch 50/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0022
# Epoch 51/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0018
# Epoch 52/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0018
# Epoch 53/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0017
# Epoch 54/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0018
# Epoch 55/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0017
# Epoch 56/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0017
# Epoch 57/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0018
# Epoch 58/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0016
# Epoch 59/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0018
# Epoch 60/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0020
# Epoch 61/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.0015
# Epoch 62/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0021
# Epoch 63/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0017
# Epoch 64/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 0.0024
# Epoch 65/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - loss: 0.0016
# Epoch 66/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - loss: 0.0016
# Epoch 67/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - loss: 0.0017
# Epoch 68/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 8s 78ms/step - loss: 0.0017
# Epoch 69/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - loss: 0.0019
# Epoch 70/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 7s 60ms/step - loss: 0.0017
# Epoch 71/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - loss: 0.0017
# Epoch 72/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.0020
# Epoch 73/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - loss: 0.0017
# Epoch 74/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0016
# Epoch 75/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 7s 62ms/step - loss: 0.0015
# Epoch 76/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 7s 65ms/step - loss: 0.0018
# Epoch 77/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 7s 63ms/step - loss: 0.0015
# Epoch 78/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - loss: 0.0016
# Epoch 79/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 7s 61ms/step - loss: 0.0016
# Epoch 80/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 9s 45ms/step - loss: 0.0015
# Epoch 81/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 52ms/step - loss: 0.0017
# Epoch 82/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0015
# Epoch 83/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0016
# Epoch 84/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0017
# Epoch 85/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0016
# Epoch 86/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0016
# Epoch 87/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0015
# Epoch 88/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.0017
# Epoch 89/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0016
# Epoch 90/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0015
# Epoch 91/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0018
# Epoch 92/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0016
# Epoch 93/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 54ms/step - loss: 0.0014
# Epoch 94/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0018
# Epoch 95/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0015
# Epoch 96/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - loss: 0.0016
# Epoch 97/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - loss: 0.0016
# Epoch 98/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - loss: 0.0018
# Epoch 99/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0017
# Epoch 100/100
# 108/108 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - loss: 0.0016

# %%
# tap test lay trong khoang tu thang 2/2024 toi thoi diem hien tai
stock = "HPG.VN"
start = dt.datetime(2024, 2, 1)
end = dt.datetime.today()
real_data_price = yf.download(stock, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
real_stock_price = real_data_price[['Close']].values

# %%
data_total = pd.concat((df['Close'], real_data_price['Close']), axis = 0)
inputs= data_total[len(data_total) - len(real_data_price) - 60:].values
inputs = np.clip(inputs, df['Close'].min(), df['Close'].max())
inputs= inputs.reshape(-1,1)
inputs = scaler.transform(inputs)

# %%
x_test = []
no_of_sample = len(inputs)

# %%
for i in range(60, no_of_sample):
    x_test.append(inputs[i-60:i, 0])

x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
predicted_stock_price = model.predict(x_test)
predicted_stock_price = scaler.inverse_transform(predicted_stock_price)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 1s 58ms/step

# %%
plt.plot(real_stock_price, color = 'red', label = 'Real  Stock Price')
plt.plot(predicted_stock_price, color = 'blue', label = 'Predicted  Stock Price')
plt.title('HPG Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('HPG Stock Price')
plt.legend()
plt.show()

# %%
# du doan trong 1 thang tiep theo
# nghia la tu bay gio den 24/03/2025


# lay 60 ngay cua tap test de tinh cac ngay tiep theo 
real_data_price = real_data_price['Close'][len(real_data_price)-60:len(real_data_price)].to_numpy()
real_data_price = np.array(real_data_price)

# %%
inputs = real_data_price
inputs = inputs.reshape(-1,1)
inputs = scaler.transform(inputs)

# %%
from datetime import  timedelta
current_date = dt.datetime(2025, 2, 27)

i=0
while i<28:
    x_test = []
    no_of_sample = len(real_data_price)

    #lay du lieu cuoi
    x_test.append(inputs[no_of_sample - 60:no_of_sample, 0])
    x_test = np.array(x_test)
    x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))
    #du doan
    predicted_stock_price = model.predict(x_test)
    #chuyen du lieu tu 0 1 thanh gia that
    predicted_stock_price = scaler.inverse_transform(predicted_stock_price)

    real_data_price = np.append(real_data_price, predicted_stock_price[0][0])

    inputs = real_data_price
    inputs = inputs.reshape(-1,1)
    inputs = scaler.transform(inputs)
    
    forecast_date = current_date + timedelta(days=i)

    print(f"Stock price {forecast_date.strftime('%d/%m/%Y')} of {stock} : {predicted_stock_price[0][0]}")

    i += 1
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# Stock price 27/02/2025 of HPG.VN : 27771.1640625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# Stock price 28/02/2025 of HPG.VN : 27878.828125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# Stock price 01/03/2025 of HPG.VN : 27944.25390625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# Stock price 02/03/2025 of HPG.VN : 28000.548828125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Stock price 03/03/2025 of HPG.VN : 28062.921875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Stock price 04/03/2025 of HPG.VN : 28134.98828125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Stock price 05/03/2025 of HPG.VN : 28214.890625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Stock price 06/03/2025 of HPG.VN : 28299.255859375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step
# Stock price 07/03/2025 of HPG.VN : 28385.189453125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Stock price 08/03/2025 of HPG.VN : 28470.8984375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Stock price 09/03/2025 of HPG.VN : 28555.630859375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Stock price 10/03/2025 of HPG.VN : 28639.3046875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Stock price 11/03/2025 of HPG.VN : 28722.173828125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# Stock price 12/03/2025 of HPG.VN : 28804.56640625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
# Stock price 13/03/2025 of HPG.VN : 28886.78125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Stock price 14/03/2025 of HPG.VN : 28968.99609375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# Stock price 15/03/2025 of HPG.VN : 29051.298828125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# Stock price 16/03/2025 of HPG.VN : 29133.72265625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# Stock price 17/03/2025 of HPG.VN : 29216.232421875
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Stock price 18/03/2025 of HPG.VN : 29298.798828125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# Stock price 19/03/2025 of HPG.VN : 29381.369140625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Stock price 20/03/2025 of HPG.VN : 29463.91015625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# Stock price 21/03/2025 of HPG.VN : 29546.380859375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# Stock price 22/03/2025 of HPG.VN : 29628.73828125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# Stock price 23/03/2025 of HPG.VN : 29710.962890625
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# Stock price 24/03/2025 of HPG.VN : 29793.021484375
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Stock price 25/03/2025 of HPG.VN : 29874.89453125
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# Stock price 26/03/2025 of HPG.VN : 29956.55078125

# %%
#dữ liệu có thể thay đổi
