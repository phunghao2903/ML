# %%
import numpy as np
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.callbacks import EarlyStopping
# Out:
# 2025-04-13 09:24:07.776479: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-04-13 09:24:07.777037: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-13 09:24:07.778966: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-04-13 09:24:07.784587: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744511047.794078   21183 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744511047.796794   21183 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-13 09:24:07.806685: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Định nghĩa mã cổ phiếu và khoảng thời gian lấy dữ liệu
ma_cophieu = "BSI.VN"
khoang_thoi_gian = "60d"  # Lấy dữ liệu trong 60 ngày gần nhất
buoc_thoi_gian = "2m"     # Khoảng thời gian 5 phút

# Tải dữ liệu từ Yahoo Finance
data = yf.download(ma_cophieu, period=khoang_thoi_gian, interval=buoc_thoi_gian)

# Kiểm tra dữ liệu
# print(data.head())
data
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# Price                        Close     High      Low     Open Volume
# Ticker                      BSI.VN   BSI.VN   BSI.VN   BSI.VN BSI.VN
# Datetime
# 2025-03-03 02:14:00+00:00  53900.0  53900.0  53600.0  53600.0      0
# 2025-03-03 02:16:00+00:00  54100.0  54100.0  53900.0  53900.0   1600
# 2025-03-03 02:18:00+00:00  54300.0  54400.0  54100.0  54100.0   7900
# 2025-03-03 02:20:00+00:00  54300.0  54400.0  54300.0  54400.0   2600
# 2025-03-03 02:22:00+00:00  54300.0  54300.0  54100.0  54200.0   5400
# ...                            ...      ...      ...      ...    ...
# 2025-04-11 07:22:00+00:00  51300.0  51300.0  51200.0  51300.0  14600
# 2025-04-11 07:24:00+00:00  51600.0  51700.0  51300.0  51300.0  50400
# 2025-04-11 07:26:00+00:00  51500.0  51700.0  51500.0  51600.0  24800
# 2025-04-11 07:28:00+00:00  51400.0  51500.0  51400.0  51500.0  12800
# 2025-04-11 07:44:00+00:00  51200.0  51200.0  51200.0  51200.0  72000
#
# [3070 rows x 5 columns]

# %%
# Lựa chọn cột giá đóng cửa và loại bỏ các giá trị NaN
data = data[['Close']].dropna()

# Chuẩn hóa dữ liệu về khoảng [0, 1]
scaler = MinMaxScaler(feature_range=(0, 1))
data_scaled = scaler.fit_transform(data)

# Chia dữ liệu thành tập huấn luyện và kiểm tra (80% huấn luyện, 20% kiểm tra)
train_size = int(len(data_scaled) * 0.8)
train_data = data_scaled[:train_size]
test_data = data_scaled[train_size:]

# Hàm tạo tập dữ liệu theo định dạng phù hợp cho LSTM
def create_dataset(dataset, time_step=50):
    X, Y = [], []
    for i in range(len(dataset) - time_step):
        X.append(dataset[i:(i + time_step), 0])
        Y.append(dataset[i + time_step, 0])
    return np.array(X), np.array(Y)

# Tạo tập huấn luyện và kiểm tra
time_step = 50  # Sử dụng 30 khoảng thời gian trước đó để dự đoán
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

# Reshape dữ liệu để phù hợp với đầu vào của LSTM (samples, time steps, features)
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# %%
# Khởi tạo mô hình LSTM
model = Sequential([
    LSTM(units=64, return_sequences=True, input_shape=(time_step, 1)),
    Dropout(0.3),
    LSTM(units=64, return_sequences=True),
    Dropout(0.3),
    LSTM(units=64),
    Dropout(0.3),
    Dense(units=1)
])

# Biên dịch mô hình
model.compile(optimizer='adam', loss='mae')

# Thiết lập hàm dừng sớm để tránh overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# Huấn luyện mô hình
history = model.fit(
    X_train, y_train,
    epochs=200,
    batch_size=30,
    validation_split=0.2,
    callbacks=[early_stopping],
    verbose=1
)
# Out:
# Epoch 1/200
# 2025-04-13 09:24:15.442628: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# /home/levanhuy/development/anaconda3/lib/python3.12/site-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 5s 43ms/step - loss: 0.2220 - val_loss: 0.0769
# Epoch 2/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0709 - val_loss: 0.0297
# Epoch 3/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0693 - val_loss: 0.0462
# Epoch 4/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0627 - val_loss: 0.0421
# Epoch 5/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0626 - val_loss: 0.0465
# Epoch 6/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0576 - val_loss: 0.0275
# Epoch 7/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0545 - val_loss: 0.0344
# Epoch 8/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0560 - val_loss: 0.0268
# Epoch 9/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0569 - val_loss: 0.0419
# Epoch 10/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0571 - val_loss: 0.0826
# Epoch 11/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0539 - val_loss: 0.0231
# Epoch 12/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0525 - val_loss: 0.0261
# Epoch 13/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0495 - val_loss: 0.0228
# Epoch 14/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0537 - val_loss: 0.0210
# Epoch 15/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0465 - val_loss: 0.0198
# Epoch 16/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0452 - val_loss: 0.0235
# Epoch 17/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0458 - val_loss: 0.0515
# Epoch 18/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0434 - val_loss: 0.0226
# Epoch 19/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 43ms/step - loss: 0.0439 - val_loss: 0.0238
# Epoch 20/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0446 - val_loss: 0.0297
# Epoch 21/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0414 - val_loss: 0.0528
# Epoch 22/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0439 - val_loss: 0.0214
# Epoch 23/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0405 - val_loss: 0.0571
# Epoch 24/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0393 - val_loss: 0.0281
# Epoch 25/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0373 - val_loss: 0.0180
# Epoch 26/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0363 - val_loss: 0.0173
# Epoch 27/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0377 - val_loss: 0.0263
# Epoch 28/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0370 - val_loss: 0.0294
# Epoch 29/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0344 - val_loss: 0.0251
# Epoch 30/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0342 - val_loss: 0.0166
# Epoch 31/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0340 - val_loss: 0.0480
# Epoch 32/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0366 - val_loss: 0.0191
# Epoch 33/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0302 - val_loss: 0.0604
# Epoch 34/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0385 - val_loss: 0.0215
# Epoch 35/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0299 - val_loss: 0.0274
# Epoch 36/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0298 - val_loss: 0.0186
# Epoch 37/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0298 - val_loss: 0.0156
# Epoch 38/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0280 - val_loss: 0.0192
# Epoch 39/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0295 - val_loss: 0.0310
# Epoch 40/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0283 - val_loss: 0.0156
# Epoch 41/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0256 - val_loss: 0.0256
# Epoch 42/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0325 - val_loss: 0.0151
# Epoch 43/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0254 - val_loss: 0.0150
# Epoch 44/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0250 - val_loss: 0.0167
# Epoch 45/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0268 - val_loss: 0.0181
# Epoch 46/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0241 - val_loss: 0.0150
# Epoch 47/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0231 - val_loss: 0.0173
# Epoch 48/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0245 - val_loss: 0.0166
# Epoch 49/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0227 - val_loss: 0.0147
# Epoch 50/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0215 - val_loss: 0.0166
# Epoch 51/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0214 - val_loss: 0.0154
# Epoch 52/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0218 - val_loss: 0.0313
# Epoch 53/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0206 - val_loss: 0.0140
# Epoch 54/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0189 - val_loss: 0.0142
# Epoch 55/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0183 - val_loss: 0.0144
# Epoch 56/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0196 - val_loss: 0.0171
# Epoch 57/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0177 - val_loss: 0.0159
# Epoch 58/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0192 - val_loss: 0.0152
# Epoch 59/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0179 - val_loss: 0.0144
# Epoch 60/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0169 - val_loss: 0.0144
# Epoch 61/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0184 - val_loss: 0.0177
# Epoch 62/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0178 - val_loss: 0.0127
# Epoch 63/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0169 - val_loss: 0.0141
# Epoch 64/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0164 - val_loss: 0.0149
# Epoch 65/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0185 - val_loss: 0.0123
# Epoch 66/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 33ms/step - loss: 0.0160 - val_loss: 0.0124
# Epoch 67/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0149 - val_loss: 0.0131
# Epoch 68/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0147 - val_loss: 0.0122
# Epoch 69/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0152 - val_loss: 0.0139
# Epoch 70/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0150 - val_loss: 0.0117
# Epoch 71/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0155 - val_loss: 0.0117
# Epoch 72/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0144 - val_loss: 0.0136
# Epoch 73/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0141 - val_loss: 0.0143
# Epoch 74/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0142 - val_loss: 0.0123
# Epoch 75/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0134 - val_loss: 0.0123
# Epoch 76/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0129 - val_loss: 0.0115
# Epoch 77/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0136 - val_loss: 0.0128
# Epoch 78/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0132 - val_loss: 0.0134
# Epoch 79/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0129 - val_loss: 0.0131
# Epoch 80/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0133 - val_loss: 0.0113
# Epoch 81/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 44ms/step - loss: 0.0137 - val_loss: 0.0104
# Epoch 82/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0138 - val_loss: 0.0108
# Epoch 83/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0131 - val_loss: 0.0103
# Epoch 84/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0121 - val_loss: 0.0132
# Epoch 85/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0124 - val_loss: 0.0101
# Epoch 86/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0120 - val_loss: 0.0102
# Epoch 87/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0128 - val_loss: 0.0106
# Epoch 88/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0124 - val_loss: 0.0114
# Epoch 89/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0131 - val_loss: 0.0144
# Epoch 90/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0130 - val_loss: 0.0147
# Epoch 91/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0122 - val_loss: 0.0118
# Epoch 92/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0114 - val_loss: 0.0106
# Epoch 93/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0120 - val_loss: 0.0178
# Epoch 94/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0130 - val_loss: 0.0146
# Epoch 95/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0125 - val_loss: 0.0094
# Epoch 96/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 39ms/step - loss: 0.0115 - val_loss: 0.0107
# Epoch 97/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0117 - val_loss: 0.0096
# Epoch 98/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0121 - val_loss: 0.0104
# Epoch 99/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0122 - val_loss: 0.0094
# Epoch 100/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0112 - val_loss: 0.0143
# Epoch 101/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0124 - val_loss: 0.0102
# Epoch 102/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 42ms/step - loss: 0.0114 - val_loss: 0.0099
# Epoch 103/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0120 - val_loss: 0.0095
# Epoch 104/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0111 - val_loss: 0.0129
# Epoch 105/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 37ms/step - loss: 0.0130 - val_loss: 0.0093
# Epoch 106/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0118 - val_loss: 0.0130
# Epoch 107/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 40ms/step - loss: 0.0123 - val_loss: 0.0100
# Epoch 108/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 38ms/step - loss: 0.0115 - val_loss: 0.0092
# Epoch 109/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0121 - val_loss: 0.0101
# Epoch 110/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0120 - val_loss: 0.0115
# Epoch 111/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - loss: 0.0118 - val_loss: 0.0125
# Epoch 112/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step - loss: 0.0118 - val_loss: 0.0096
# Epoch 113/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0115 - val_loss: 0.0112
# Epoch 114/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0113 - val_loss: 0.0092
# Epoch 115/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 35ms/step - loss: 0.0107 - val_loss: 0.0119
# Epoch 116/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - loss: 0.0114 - val_loss: 0.0095
# Epoch 117/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - loss: 0.0108 - val_loss: 0.0103
# Epoch 118/200
# 65/65 ━━━━━━━━━━━━━━━━━━━━ 3s 41ms/step - loss: 0.0112 - val_loss: 0.0105

# %%
# Dự đoán trên tập kiểm tra
y_pred = model.predict(X_test)

# Đưa dữ liệu dự đoán và thực tế về giá trị gốc
y_pred_inv = scaler.inverse_transform(y_pred)
y_test_inv = scaler.inverse_transform(y_test.reshape(-1, 1))

# Vẽ biểu đồ so sánh giá thực tế và giá dự đoán
plt.figure(figsize=(14, 5))
plt.plot(data.index[train_size + time_step:], y_test_inv, color='blue', label='Giá thực tế')
plt.plot(data.index[train_size + time_step:], y_pred_inv, color='red', label='Giá dự đoán')
plt.title('Dự đoán giá cổ phiếu với LSTM')
plt.xlabel('Thời gian')
plt.ylabel('Giá cổ phiếu')
plt.legend()
plt.show()



# y_pred = model.predict(X_test)
# y_pred = scaler.inverse_transform(y_pred)
# y_test_actual = scaler.inverse_transform(y_test.reshape(-1, 1))

# Tính các metrics
from sklearn.metrics import mean_squared_error, mean_absolute_error
rmse = np.sqrt(mean_squared_error(y_test_inv, y_pred_inv))
mae = mean_absolute_error(y_test_inv, y_pred_inv)
mape = np.mean(np.abs((y_test_inv - y_pred_inv) / y_test_inv)) * 100

print(f"RMSE: {rmse}")
print(f"MAE: {mae}")
print(f"MAPE: {mape}%")
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step
# RMSE: 707.2031236381907
# MAE: 531.8220370678191
# MAPE: 1.0905816924310825%

# %%
from sklearn.metrics import mean_absolute_percentage_error

mape = mean_absolute_percentage_error(y_test_inv, y_pred_inv) * 100
print(f"MAPE: {mape:.2f}%")

# Đánh giá trên tập test
# Out:
# MAPE: 1.09%

# %%
# Giả sử 'model' là mô hình LSTM đã được huấn luyện
model.save('/home/phung/jnotebook/source/Tuan12/model/predict_BSI_1_40_d.keras')
